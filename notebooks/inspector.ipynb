# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
data_dir = Path("../data")
merge = data_dir / "merged"
test = data_dir / "test"

# %%
merge_proveedores = merge / "proveedores_final-merged.csv"
merge_donantes = merge / "donantes_final-merged.csv"
test_proveedores = test / "proveedores_final-merged.csv"
test_donantes = test / "donantes_final-merged.csv"

# %%
dfdt = pd.read_csv(test_donantes)
dfpt = pd.read_csv(test_proveedores)
dfdm = pd.read_csv(merge_donantes)
dfpm = pd.read_csv(merge_proveedores)
# Out:
#    Numero                 Nombre     Tipo    Contacto  \
# 0  D00001     TechNova Solutions  Empresa  Contacto A
# 1  D00002       EnergiaPlus S.A.  Empresa  Contacto B
# 2  D00003            Grupo Delta  Empresa  Contacto C
# 3  D00004           Inova Global  Empresa  Contacto D
# 4  D00005  Vanguardia Consultora  Empresa  Contacto E
#
#                   Correo Electronico         Telefono  Observaciones  \
# 0     TechNova Solutions@example.com  (011) 5000-0001  Observación 1
# 1       EnergiaPlus S.A.@example.com  (011) 5000-0002  Observación 2
# 2            Grupo Delta@example.com  (011) 5000-0003  Observación 3
# 3               Inova Global@example  (011) 5000-0004  Observación 4
# 4  Vanguardia Consultora@example.com  (011) 5000-0005  Observación 5
#
#   Razon Social  Tipo de Contribuyente           CUIT        Alta        Baja  \
# 0        S.R.L  Responsable Inscripto  20-12345678-9  2024-02-26  2023-01-29
# 1          S.A         Monotributista  21-23456789-0  2024-01-12  2023-06-25
# 2        S.R.L  Responsable Inscripto  22-34567890-1  2024-06-08         NaN
# 3        S.R.L         Monotributista  23-45678901-2  2024-02-11  2023-03-05
# 4        S.R.L  Responsable Inscripto  24-56789012-3  2024-05-29         NaN
#
#   Activo Frecuencia     Importe  Nro de Cuenta       Pais      Mes
# 0     NO    Mensual  292.732,00         402101   Colombia  Febrero
# 1     NO  Bimestral  326.439,00         403101   Colombia    Enero
# 2     SI      Anual  276.920,00         403101   Paraguay    Junio
# 3     NO    Mensual  406.733,00         402101    Bolivia  Febrero
# 4     SI  Bimestral  352.572,00         403101  Argentina     Mayo
