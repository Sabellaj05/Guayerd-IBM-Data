# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# Datosss
# Guayred data.ipynb

# %%
data_d = "Datosss/Copy of NO TOCAR (NO EDITAR)Donantes - Donantes (1).csv"
data_p = "Datosss/Copy of NO TOCAR (NO EDITAR)Proveedores.xlsx"

dfd = pd.read_csv(data, delimiter=";")
dfp = pd.read_excel(data_p)
dfd.head()
# Out:
#    Número                 Nombre     Tipo    Contacto Cargo  \
# 0  D00001     TechNova Solutions  Empresa  Contacto A     -
# 1  D00002       EnergiaPlus S.A.  Empresa  Contacto B     -
# 2  D00003            Grupo Delta  Empresa  Contacto C     -
# 3  D00004           Inova Global  Empresa  Contacto D     -
# 4  D00005  Vanguardia Consultora  Empresa  Contacto E     -
#
#                   Correo Electrónico         Teléfono  Observaciones  \
# 0     TechNova Solutions@example.com  (011) 5000-0001  Observación 1
# 1       EnergiaPlus S.A.@example.com  (011) 5000-0002  Observación 2
# 2            Grupo Delta@example.com  (011) 5000-0003  Observación 3
# 3               Inova Global@example  (011) 5000-0004  Observación 4
# 4  Vanguardia Consultora@example.com  (011) 5000-0005  Observación 5
#
#   Razon Social  Tipo de Contribuyente           CUIT   Alta     Baja Activo  \
# 0        S.R.L  Responsable Inscripto  20-12345678-9  45348  45383.0     NO
# ...

# %%
dfp.head()
# Out:
#   Número Proveedor       Nombre Proveedor           CUIT Categor/a Proveedor  \
# 0           P00100       Gabriela Morales  30-98765437-1         MATER/IALES
# 1           P00099    Servicios Repuestos  30-45678910-0           SERVIC/OS
# 2           P00098       Consultora Alpha  30-32165492-9         MATER/IALES
# 3           P00097  Proveedora Consultora  30-19283755-8           SERVIC/OS
# 4           P00096      Mariana Fernández  30-86430987-7         MATER/IALES
#
#    Tipo de Contribuyente  Observaciones               Contacto  \
# 0         MONOTRIBUTISTA            NaN       Gabriela Morales
# 1  RESPONSABLE INSCR/ITO            NaN    Servicios Repuestos
# 2         MONOTRIBUTISTA            NaN       Consultora Alpha
# 3  RESPONSABLE INSCR/ITO            NaN  Proveedora Consultora
# 4         MONOTRIBUTISTA            NaN      Mariana Fernández
#
#                   Correo Electrónico   Teléfono Razón Social  Importe  \
# ...

# %%
dfp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Número Proveedor       155 non-null    object
#  1   Nombre Proveedor       155 non-null    object
#  2   CUIT                   150 non-null    object
#  3   Categor/a Proveedor    155 non-null    object
#  4   Tipo de Contribuyente  155 non-null    object
#  5   Observaciones          0 non-null      float64
#  6   Contacto               155 non-null    object
#  7   Correo Electrónico     155 non-null    object
#  8   Teléfono               155 non-null    object
#  9   Razón Social           155 non-null    object
#  10  Importe                155 non-null    int64
#  11  Fecha                  155 non-null    datetime64[ns]
#  12  Nro_Cuenta             155 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 15.9+ KB

# %%
dfp.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Número Proveedor       0 non-null      object
#  1   Nombre Proveedor       0 non-null      object
#  2   CUIT                   0 non-null      object
#  3   Categor/a Proveedor    0 non-null      object
#  4   Tipo de Contribuyente  0 non-null      object
#  5   Observaciones          0 non-null      float64
#  6   Contacto               0 non-null      object
#  7   Correo Electrónico     0 non-null      object
#  8   Teléfono               0 non-null      object
#  9   Razón Social           0 non-null      object
#  10  Importe                0 non-null      int64
#  11  Fecha                  0 non-null      datetime64[ns]
#  12  Nro_Cuenta             0 non-null      int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 0.0+ bytes

# %%
dfp
# Out:
#     Número Proveedor       Nombre Proveedor           CUIT  \
# 0             P00100       Gabriela Morales  30-98765437-1
# 1             P00099    Servicios Repuestos  30-45678910-0
# 2             P00098       Consultora Alpha  30-32165492-9
# 3             P00097  Proveedora Consultora  30-19283755-8
# 4             P00096      Mariana Fernández  30-86430987-7
# ..               ...                    ...            ...
# 150           P00077       Javier Rodríguez  30-45678908-8
# 151           P00076    Repuestos Beta S.A.  30-32165490-7
# 152           P00075   Servicios Alpha S.A.  30-19283753-6
# 153           P00074         Proveedora SRL  30-86430982-5
# 154           P00073          Andrés García  30-97531251-4
#
#     Categor/a Proveedor  Tipo de Contribuyente  Observaciones  \
# 0           MATER/IALES         MONOTRIBUTISTA            NaN
# 1             SERVIC/OS  RESPONSABLE INSCR/ITO            NaN
# 2           MATER/IALES         MONOTRIBUTISTA            NaN
# ...
